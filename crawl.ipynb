# %%
import json
import requests
import re
from bs4 import BeautifulSoup
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import unicodedata
from tqdm import tqdm

# %%
text = "ChuyÃªn cÄn há» Masteri Tháº£o Äiá»n giÃ¡ ráº» nháº¥t thá» trÆ°á»ng, há» trá»£ vay 80%. LH0936 721 ***Mr. HoÃ i"
# fix text 
def fix_text(text):
    # Remove accents
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore').decode('utf-8')
    return text
fix_text(text)
# Out:
# 'ChuyAn cAn ha Masteri Thao Aian giA ra nhat tha trang, ha tra vay 80%. LH0936 721 ***Mr. HoA i'

# %%
def fetch_and_save_data(start_page, end_page, output_file):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) Gecko/20100101 Firefox/91.0',
        'Referer': 'https://www.google.com/',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
        'Connection': 'keep-alive',
        'Cache-Control': 'no-cache',
        'Pragma': 'no-cache',
        'Accept-Language': 'vi-VN,vi;q=0.9'
    }
    data_list = []

    session = requests.Session()

    # Adding a retry mechanism to handle transient errors
    retry = Retry(connect=3, backoff_factor=0.5)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    proxies = None  # Set to None to disable proxy

    for page in tqdm(range(start_page, end_page + 1), desc="Fetching pages"):
        url = f"https://batdongsan.com.vn/ban-can-ho-chung-cu/p{page}"
        response = session.get(url, headers=headers, proxies=proxies)
        print(f"Fetching page {page}: Status code {response.status_code}")
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            link_sample = soup.find_all('a', class_='js__product-link-for-product-id')
            for link in link_sample:
                href = link.get('href')
                if href:
                    sub_url = f"https://batdongsan.com.vn{href}"
                    sample_res = session.get(sub_url, headers=headers, proxies=proxies)
                    sample = BeautifulSoup(sample_res.text, 'html.parser')
                    try:
                        title = sample.find('h1', class_='re__pr-title pr-title js__pr-title')
                        if title:
                            title = title.get_text(strip=True)
                            title = title.encode(sample_res.encoding).decode('utf-8', errors='ignore')
                        else:
                            title = None

                        description = sample.find('div', class_='re__section-body re__detail-content js__section-body js__pr-description js__tracking')
                        if description:
                            description = description.get_text(strip=True)
                            description = description.encode(sample_res.encoding).decode('utf-8', errors='ignore')
                        else:
                            description = None
                        
                        location = sample.find('span', class_='re__pr-short-description js__pr-address')
                        if location:
                            location = location.get_text(strip=True)
                            location = location.encode(sample_res.encoding).decode('utf-8', errors='ignore')
                        else:
                            location = None
                        
                        img_source = sample.find('div', class_='re__media-thumbs js__media-thumbs')

                        images = []
                        if img_source:
                            img_html = str(img_source)
                            # Use re.findall to extract all data-src links
                            image_links = re.findall(r'data-src="(.*?)"', img_html)
                            for image in image_links:
                                image = image.encode(sample_res.encoding).decode('utf-8', errors='ignore')
                                images.append(image)
                            
                        data = {
                            'title': title,    
                            'description': description,
                            'price': None,
                            'area': None,
                            'bedrooms': None,
                            'bathrooms': None,
                            'direction': None,
                            'bal_direction': None,
                            'legal': None,
                            'furniture': None,
                            'location': location,
                            'link': sub_url,
                            'image': images
                        }
                        
                        feature = sample.find_all('div', class_='re__pr-specs-content-item')
                        if feature:
                            for item in feature:
                                if item:
                                    check = item.find('span', class_='re__pr-specs-content-item-title')
                                    check = check.get_text(strip=True).encode(sample_res.encoding).decode('utf-8', errors='ignore')
                                    if "Mức giá" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        price = item.get_text(strip=True)
                                        data['price'] = price
                                    elif "Diện tích" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        area = re.sub(r'[^\d,]', '', str(item))
                                        data['area'] = area
                                    elif "Số phòng ngủ" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        bedrooms = re.sub(r'[^\d,]', '', str(item))
                                        data['bedrooms'] = bedrooms
                                    elif "Số phòng tắm, vệ sinh" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        bathrooms = re.sub(r'[^\d,]', '', str(item))
                                        data['bathrooms'] = bathrooms
                                    elif "Hướng nh" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        direction = re.sub(r'<.*?>', '', str(item))
                                        data['direction'] = direction
                                    elif "Hướng ban công" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        bal_direction = re.sub(r'<.*?>', '', str(item))
                                        data['bal_direction'] = bal_direction
                                    elif "Pháp lý" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        legal = (lambda x: "Hợp đồng mua bán" if ("Sổ hồng lâu dài" if ("lâu dài" in x or "Sổ hồng lâu dài" in x) else "Hợp đồng" in x or "Hợp đồng mua bán" in x) else "Sổ đỏ/ Sổ hồng" if ("Sổ đỏ" in x or "Sổ hồng" in x) else None)(item.get_text(strip=True))
                                        data['legal'] = legal
                                    elif "Nội thất" in check:
                                        item = item.find('span', class_='re__pr-specs-content-item-value')
                                        furniture = (lambda x: "Cao cấp" if "Cao cấp" in x else "Đầy đủ" if "Đầy đủ" in x else "Cơ bản" if "Cơ bản" in x else None)(item)
                                        data['furniture'] = furniture

                        data_list.append(data)
                    except AttributeError:
                        print("An element is missing some fields, skipping...")
        else:
            print(f"Failed to retrieve page {page}")
    
    with open(output_file, 'w', encoding='utf-8') as file:
        json.dump(data_list, file, ensure_ascii=False, indent=4)

fetch_and_save_data(12, 16, 'data.json')
# Out:
# Fetching pages:   0%|          | 0/5 [00:00<?, ?it/s]
# Fetching page 12: Status code 200
# Fetching pages:  60%|██████    | 3/5 [00:03<00:01,  1.08it/s]
# Fetching page 13: Status code 403
# Failed to retrieve page 13
# Fetching page 14: Status code 403
# Failed to retrieve page 14
# Fetching pages:  80%|████████  | 4/5 [00:04<00:00,  1.57it/s]
# Fetching page 15: Status code 403
# Failed to retrieve page 15
# Fetching page 16: Status code 200
# Fetching pages: 100%|██████████| 5/5 [00:11<00:00,  2.24s/it]

# %%
# Đoạn văn bản HTML
text = '<span class="re__pr-specs-content-item-value">24,5 tỷ</span>'

# Sử dụng re.sub để loại bỏ thẻ HTML
content = re.sub(r'<.*?>', '', text)

print(content)
# Out:
# 24,5 tỷ

# %%
headers = {
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) Gecko/20100101 Firefox/91.0',
	'Accept-Language': 'en-US,en;q=0.9',
	'Referer': 'https://www.google.com/',
	'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
	'Connection': 'keep-alive',
	'Cache-Control': 'no-cache',
	'Pragma': 'no-cache'
}
data_list = []

url = "https://batdongsan.com.vn/ban-can-ho-chung-cu"
session = requests.Session()

# Adding a retry mechanism to handle transient errors

retry_strategy = Retry(
	total=3,
	backoff_factor=1,
	status_forcelist=[403, 500, 502, 503, 504],
	allowed_methods=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)
session.mount("https://", adapter)
# Remove the proxy settings or replace with valid proxy details
proxies = None  # Set to None to disable proxy

response = session.get(url, headers=headers, proxies=proxies)
if response.status_code == 403:
	print("Access forbidden. Check headers or try using a different proxy.")
else:
	response.raise_for_status()

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="vi">
# <head>
# <link href="https://staticfile.batdongsan.com.vn" rel="preconnect"/>
# <link href="https://staticfile.batdongsan.com.vn" rel="dns-prefetch"/>
# <link href="https://file4.batdongsan.com.vn" rel="preconnect"/>
# <link href="https://file4.batdongsan.com.vn" rel="dns-prefetch"/>
# <script src="https://staticfile.batdongsan.com.vn/js/Common/Global/filestatic.ver11.msvbds.SyncFunctions.min.js" type="text/javascript"></script>
# <script>
#             window.unlFeatures = [{"f":"cplus-9046_new-pa-entry-point","v":"cplus-9046_new-pa-entry-point_version-c","s":"1"},{"f":"cplus-8015_implement-ui-message","v":"cplus-8015_implement-ui-message_version-a","s":"1"},{"f":"cplus-8842_new-label-verified-listing","v":"disabled","s":"0"},{"f":"cplus-9084_unified-search-srp-map-and-list","v":"cplus-9084_unified-search-srp-map-and-list_enabled","s":"1"},{"f":"BDSMON2-PIVOT-CONSUMER","v":"","s":"1"},{"f":"cplus-8431-braze-web-push","v":"","s":"1"},{"f":"cplus-8350_new-categories-mini-apartment","v":"","s":"1"},{"f":"cplus-8336-customized-srp-bottom-pages","v":"","s":"1"},{"f":"cplus-8478_KYC-bookmark-listing","v":"","s":"1"},{"f":"cplus-7797_promote-listing-verified-for-city","v":"","s":"1"},{"f":"cplus-8597_Label-cate-mini-apartment","v":"","s":"1"},{"f":"cplus-7974-braze-integration","v":"","s":"1"},{"f":"onboarding-new-users","v":"","s":"0"},{"f":"BDSMON2-PIVOT-ENTRY-TOP-MENU-CONSUMER","v":"","s":"1"},{"f":"cloudflare-turnstile-viewphone","v":"","s":"0"},{"f":"cplus-7677-kong-api-gateway-integration","v":"","s":"0"},{"f":"cplus-8907_banner-placeholder-on-map-search","v":"","s":"0"},{"f":"bdspp-947-leadgen-ldp","v":"","s":"0"},{"f":"cplus-7974-braze-in-app-message","v":"","s":"0"},{"f":"cplus-8127-move-seo-controller-to-seo-listing-service","v":"","s":"1"},{"f":"cplus_7967-image-optimize","v":"","s":"1"},{"f":"cloudflare-turnstile-ppp","v":"","s":"0"},{"f":"cplus-7406_new-api-suggestion","v":"","s":"0"},{"f":"cplus-9386_pa-link-parameters","v":"","s":"1"},{"f":"cplus-8389_ms-sort-render-srp-ajax","v":"","s":"0"}];
#         </script>
# <script type="text/javascript">
#         window.pageTrackingData = {
#             ...JSON.parse('{"pageTrackingType":"SRP","products":[{"intent":"Sale","pageType":"SRP","productId":42811574,"projectId":5619,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":8,"wardId":9484,"streetId":10414,"pageId":275,"createByUser":1778007,"productType":0},{"intent":"Sale","pageType":"SRP","productId":39114589,"projectId":2766,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":11,"wardId":9995,"streetId":0,"pageId":275,"createByUser":543181,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42777869,"projectId":5420,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"SG","districtId":61,"wardId":5850,"streetId":0,"pageId":275,"createByUser":3981164,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42714850,"projectId":6274,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HY","districtId":339,"wardId":877,"streetId":0,"pageId":275,"createByUser":1930600,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42793311,"projectId":6221,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":11,"wardId":9997,"streetId":0,"pageId":275,"createByUser":140621,"productType":0},{"intent":"Sale","pageType":"SRP","productId":41850299,"projectId":2766,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":11,"wardId":9995,"streetId":8770,"pageId":275,"createByUser":3441643,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42810650,"projectId":5523,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"SG","districtId":71,"wardId":137,"streetId":11233,"pageId":275,"createByUser":3580617,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42789560,"projectId":2711,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"SG","districtId":61,"wardId":5849,"streetId":0,"pageId":275,"createByUser":2667200,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42800493,"projectId":6274,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HY","districtId":339,"wardId":877,"streetId":0,"pageId":275,"createByUser":1667920,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42665977,"projectId":2766,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":11,"wardId":9995,"streetId":0,"pageId":275,"createByUser":4338436,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42509557,"projectId":5562,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"VT","districtId":102,"wardId":12099,"streetId":2656,"pageId":275,"createByUser":1897894,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42287004,"projectId":1404,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":718,"wardId":11376,"streetId":626,"pageId":275,"createByUser":2859322,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42810018,"projectId":5279,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"BD","districtId":158,"wardId":1001,"streetId":8005,"pageId":275,"createByUser":1928470,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42603817,"projectId":5328,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"SG","districtId":61,"wardId":5850,"streetId":5558,"pageId":275,"createByUser":582089,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42569053,"projectId":2711,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"SG","districtId":61,"wardId":5849,"streetId":0,"pageId":275,"createByUser":642473,"productType":0},{"intent":"Sale","pageType":"SRP","productId":42263840,"projectId":5964,"vipType":0,"verified":false,"expired":false,"cateId":324,"cityCode":"HN","districtId":14,"wardId":11377,"streetId":0,"pageId":275,"createByUser":267806,"productType":0},{"intent":"Sale","pageType":"SRP","product ...
#             bdsUuid: "a7f27aef-8eb6-44ca-b3a2-59f83c662e1d",
#             isSegmentIdentify: false,
#         };
#     </script>
# <script>
#     !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on","addSourceMiddleware","addIntegrationMiddleware","setAnonymousId","addDestinationMiddleware"];analytics.factory=function(e){return function(){if(window.analytics.initialized)return window.analytics[e].apply(window.analytics,arguments);var i=Array.prototype.slice.call(arguments);i.unshift(e);analytics.push(i);return analytics}};for(var i=0;i<analytics.methods.length;i++){var key=analytics.methods[i];analytics[key]=analytics.factory(key)}analytics.load=function(key,i){var t=document.createElement("script");t.type="text/javascript";t.async=!0;t.src="https://cdn.segment.com/analytics.js/v1/" + key + "/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n);analytics._loadOptions=i};analytics._writeKey="W4EsSW2yr56lXiy6zXJobIL8E7wZVaLt";;analytics.SNIPPET_VERSION="4.16.1";
#       analytics.load("W4EsSW2yr56lXiy6zXJobIL8E7wZVaLt");
#       let data = window.pageTrackingData;
#       if (data && data.bdsUuid){
#           analytics.setAnonymousId(data.bdsUuid);
#       }
#       const isLogin = window.userServices && window.userServices.currentUserInfo;
#       if (data && data.pageTrackingType == 'LDP' && data.products && (isLogin || data.isSegmentIdentify)) {
#         const productInfo = data.products[0];
#         if (productInfo){
#             const props = {
#                 eventData: {
#                     intent: productInfo.intent,
#                     pageType: productInfo.pageType,
#                     productId: productInfo.productId
#                 },
#                 metaData: {
#                     projectId: productInfo.projectId,
#                     vipType: productInfo.vipType,
#                     verified: productInfo.verified,
#                     expired: productInfo.expired,
#                     cateId: productInfo.cateId,
#                     cityCode: productInfo.cityCode,
#                     districtId: productInfo.districtId,
#                     wardId: productInfo.wardId,
#                     streetId: productInfo.streetId,
#                     pageId: productInfo.pageId
#                 }
#             }
#             analytics.track("LdpPageViewed", props)
#         }
#       }
#     }}();
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/segment-analytics/filestatic.ver3.msvbds.SegmentClient.min.js" type="text/javascript"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#
#     var data = {
#                 'event': 'pageInfo',
#                 'cat': '324','dtk': 'null',
#                 'ite': '',
#                 'pag': '275',
#                 'cit': 'null',
#                 'dis': 'null',
#                 'war': 'null',
#                 'str': 'null',
#                 'pro': 'null',
#                 'pri': 'null',
#                 'mip': 'null',
#                 'map': 'null',
#                 'are': 'null',
#                 'mia': 'null',
#                 'maa': 'null',
#                 'dir': 'null',
#                 'rom': 'null',
#                 'vrs': '0',
#                 'unl': window.unlFeatures,
#             };;
#
#     window.dataLayer.push(data);
# </script>
# <!-- Google Tag Manager -->
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#             'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-MMVJT5G');
# </script>
# <!-- End Global site tag (gtag.js) - Google Analytics -->
# <!-- End Google Tag Manager -->
# <script async="" data-ad-client="ca-pub-4522977639867868" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#         window.enablePPPImpression = true;
#     </script>
# <link href="https://batdongsan.com.vn/ban-can-ho-chung-cu" hreflang="vi-vn" rel="alternate"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/symbol-only.svg" rel="shortcut icon" type="image/svg+xml"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_57x57.png" rel="icon" sizes="57x57" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_152x152.png" rel="icon" sizes="152x152" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_144x144.png" rel="icon" sizes="144x144" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_120x120.png" rel="icon" sizes="120x120" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_114x114.png" rel="icon" sizes="114x114" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_76x76.png" rel="icon" sizes="76x76" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_72x72.png" rel="icon" sizes="72x72" type="image/png"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_57x57.png" rel="nokia-touch-icon"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_114x114.png" rel="apple-touch-icon" sizes="1x1"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/favicon_sisu_72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://staticfile.batdongsan.com.vn/images/logo/symbol-only.svg" rel="apple-touch-icon"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="general" http-equiv="audience">
# <meta content="document" name="resource-type"/>
# <meta content="ThÃ´ng tin nhÃ  Äáº¥t Viá»t Nam" name="abstract"/>
# <meta content="Báº¥t Äá»ng sáº£n Viá»t Nam" name="classification"/>
# <meta content="NhÃ  Äáº¥t vÃ  báº¥t Äá»ng sáº£n" name="area"/>
# <meta content="Viá»t Nam" name="placename"/>
# <meta content="Batdongsan.com.vn" name="author"/>
# <meta content="Â©2007 Batdongsan.com.vn" name="copyright"/>
# <meta content="Batdongsan.com.vn" name="owner"/>
# <meta content="CÃ´ng ty Cá» pháº§n PropertyGuru Viá»t Nam" name="generator"/>
# <meta content="Global" name="distribution"/>
# <meta content="1 days" name="revisit-after"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://batdongsan.com.vn/ban-can-ho-chung-cu" rel="canonical">
# <meta content="app-id=866492094" name="custom-apple-itunes-app"/>
# <meta content="mua, bÃ¡n, cÄn há», chung cÆ°, giÃ¡ ráº», toÃ n quá»c, hÃ  ná»i, hcm" name="keywords"/>
# <meta content="Thông tin mua bán cÄn há» chung cÆ° giá ráº» toàn quá»c, cáº­p nháº­t thông tin thá» trÆ°á»ng mua bán cÄn há» chung cÆ° nhanh nháº¥t, chính xác nháº¥t má»i ngày." name="description"/>
# <title>Bán CÄn Há» Chung CÆ° Toàn Quá»c Giá Ráº» | Thông Tin Chính Xác</title>
# <meta content="302507473246792" property="fb:app_id"/><meta content="Bán CÄn Há» Chung CÆ° Toàn Quá»c Giá Ráº» | Thông Tin Chính Xác" property="og:title"/><meta content="Thông tin mua bán cÄn há» chung cÆ° giá ráº» toàn quá»c, cáº­p nháº­t thông tin thá» trÆ°á»ng mua bán cÄn há» chung cÆ° nhanh nháº¥t, chính xác nháº¥t má»i ngày." property="og:description"/><meta content="https://file4.batdongsan.com.vn/crop/600x315/2025/04/23/20250423234527-0d67_wm.jpg" property="og:image"/><meta content="600" property="og:image:width"/><meta content="315" property="og:image:height"/><meta content="website" property="og:type"/><meta content="https://batdongsan.com.vn/ban-can-ho-chung-cu" property="og:url"/>
# <link href="https://batdongsan.com.vn/ban-can-ho-chung-cu/p2" rel="next">
# <link href="https://staticfile.batdongsan.com.vn/js/fancy2.0/source/jquery.fancybox.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/js/fancy2.0/source/helpers/jquery.fancybox-buttons.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/js/jquery-ui.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/fontawesomeMSV/css/font-awesome.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/jquery.mCustomScrollbar.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/filestatic.verm-c499fc3.msvbds.addStyle.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/web/filestatic.verm-c499fc3.msvbds.layout.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/lib/jquery-swiper/css/swiper.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/lib/bds-tooltip/filestatic.ver2.msvbds.bds-tooltip.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/lib/microtip/microtip.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/swiper.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/lib/jquery-mCustomScrollbar/css/jquery.mCustomScrollbar.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/Product/filestatic.verm-c499fc3.msvbds.Product.Header.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/Product/filestatic.verm-c499fc3.msvbds.Product.Box.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/web/filestatic.verm-c499fc3.msvbds.srp.min.css" rel="stylesheet">
# <link href="https://staticfile.batdongsan.com.vn/css/web/filestatic.verm-c499fc3.msvbds.listing-search-section.min.css" rel="stylesheet"/>
# <link href="https://staticfile.batdongsan.com.vn/css/web/filestatic.verm-c499fc3.msvbds.promoted-project.min.css" rel="stylesheet"/>
# <script src="https://staticfile.batdongsan.com.vn/js/Common/filestatic.ver4.msvbds.Common.CacheHelper.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/filestatic.ver7.msvbds.speedup.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Global/filestatic.ver9.msvbds.Extensions.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Global/filestatic.ver39.msvbds.Services.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/filestatic.ver4.msvbds.Common.State.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/UIHelpers/filestatic.ver89.msvbds.FrontEnd.KycLoadingHelper.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Origins/Layout/filestatic.ver30.msvbds.FrontEnd.UserInfo.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.ver4.msvbds.FrontEnd.SearchingHistoriesServices.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.ver5.msvbds.FrontEnd.YourLocationServices.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.ver16.msvbds.FrontEnd.SearchingSuggestionServices.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.ver5.msvbds.FrontEnd.LocationsServices.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.ver17.msvbds.FrontEnd.ListingSearchSelectController.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.ver17.msvbds.FrontEnd.PieChartSelectController.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.ver14.msvbds.FrontEnd.ListingSearchFilterSelectionController.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.ver5.msvbds.FrontEnd.ListingSearchTagController.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/UIHelpers/filestatic.ver5.msvbds.FrontEnd.ListingSearchHistoryHelper.min.js" type="text/javascript">
# </script>
# <script src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/filestatic.verm-c499fc3.msvbds.FrontEnd.AdvancedFilter.Helpers.min.js" type="text/javascript"></script>
# <script searching-histories-service-params='{"maxSearchingHistoriesLength":20,"syncTimeSearchingHistories":5.0,"syncSearchingHistoriesUrl":"/Product/ProductSearch/SyncSearchingHistories","removeSearchingHistoryUrl":"/Product/ProductSearch/RemoveSearchingHistory"}' searching-suggestions-service-params='{"hours":2.0,"trackingInfo":{"id":"search-bar-suggestion","project":"project","location":"location","history":"history","nearMe":"near me"}}'></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.verm-c499fc3.msvbds.FrontEnd.SearchingTrackingService.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.verm-c499fc3.msvbds.FrontEnd.SearchingHistoriesServices.LocationFocus.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.ver17.msvbds.FrontEnd.PieChartSelectController.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Location.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Multiple.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Range.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Single.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Tag.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Toggle.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/FilterController/filestatic.verm-c499fc3.msvbds.FrontEnd.FilterController.Pie.Common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/filestatic.verm-c499fc3.msvbds.FrontEnd.AdvancedFilter.OverviewModal.SelectionRender.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.BoxListingSearchAdvancedFilter.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.ListingSearchAdvancedFilter.common.min.js" type="text/javascript">
# </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/filestatic.verm-c499fc3.msvbds.FrontEnd.AdvancedFilter.OverviewModal.min.js" type="text/javascript">
# </script>
# <script src="https://staticfile.batdongsan.com.vn/js/Components/SearchControl/filestatic.verm-c499fc3.msvbds.FrontEnd.AdvancedFilter.Helpers.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" integrity="sha384-viDHjsU4XEZbt0unbMyyJOhjh+9cZLSqGOiLH2UePQay1WvXyJc+Pv5Ez7BGv9ji" src="https://browser.sentry-cdn.com/7.59.2/bundle.tracing.replay.min.js"></script>
# <script>
#         Sentry.onLoad(function () {
#             Sentry.init({
#                 environment: "production",
#                 dsn: "https://ac0e80162bfc40348aa4b34cd05d9924@sentry.propertyguru.com/226",
#                 release: "consumer@1.0.20",
#                 integrations: [new Sentry.BrowserTracing()],
#                 tracesSampleRate: 1,
#                 tracePropagationTargets: ["/^https:\\/\\/batdongsan\\.com\\.vn\\/"],
#                 ignoreErrors: ["Failed to read the 'localStorage' property from 'Window': Access is denied for this document.","Object captured as exception with keys","Object captured as promise rejection with keys","Non-Error promise rejection captured with value","AdsBot-Google","AdButler","zaloJSV2","undefined is not an object (evaluating 'a.L')","The operation is insecure.","JSONP request failed.","Load failed","[Cloudflare Turnstile] Error: 300030.","[Cloudflare Turnstile] Error: 110600.","[Cloudflare Turnstile] Error: 300031.","[Cloudflare Turnstile] Error: 300010.","[Cloudflare Turnstile] Error: 600010.","[Cloudflare Turnstile] Error: 100040.","[Cloudflare Turnstile] Error: 106010.","[Cloudflare Turnstile] Error: 106030.","Can't find variable: HTMLDialogElement","Could not load \"map\"."]
#             });
#             window.waitObject("userServices").then(function (userServices) {
#                 window.userServices.getCurrentUserInfo().then(function (user) {
#                     if (!user) {
#                         return;
#                     }
#                     Sentry.setUser({ id: user.userid });
#                 });
#             });
#         });
#     </script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Origins/Binnova/filestatic.verm-c499fc3.msvbds.FrontEnd.GAMBannerViewer.min.js" type="text/javascript"></script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Origins/Binnova/filestatic.ver5.msvbds.FrontEnd.GAMBannerScript.min.js" type="text/javascript"></script>
# <script>
#     window.googletag = window.googletag || { cmd: [] };
# </script>
# </link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></meta></head>
# <body class="re__body re__body-srp re__srp-list-view" itemscope="" itemtype="https://schema.org/WebPage" onpageshow="hideLoading()">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MMVJT5G" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <span class="pivot-menu"></span>
# <span class="pivot-banner"></span>
# <div class="form-content">
# <div class="js__tracking-configs" data-access-sellernet-homepage-from-overview-btn-id="access-sellernet-homepage-from-overview-btn" data-braze-close-tracking-id="click-braze-close-button" data-kyc-close-popup-tracking-id="kyc-close-popup" data-kyc-validate-otp-result="kyc-validate-otp-result" data-sign-out-tracking-id="sign-out" data-sign-out-tracking-label-page-group="consumer_page">
# </div>
# <div class="js__user-services-params" data-get-bot-user-info="/Systems/Account/GetBotUserById" data-get-current-user-info="/Systems/Account/GetCurrentUserInfo" data-get-notification-count="/Systems/Account/GetNotificationCount" data-get-refresh-token="/api/v1/User/RefreshToken" data-is-local-development-token="False" data-logout="/Systems/Account/Logout" data-refresh-token="/Systems/Account/RefreshToken"></div>
# <div class="hide" data-api-router="/api" data-appidforfb="302507473246792" data-content="https://batdongsan.com.vn" data-cssserver="https://staticfile.batdongsan.com.vn" data-domainorigin="batdongsan.com.vn" data-fileimg="https://file4.batdongsan.com.vn" data-is-mobile="false" data-kong-gw-domain="https://kgw.batdongsan.com.vn/consumer/frontend" data-msvrouter="/microservice-architecture-router" data-msvrouter-personal="/microservice-architecture-router-personal" data-new-api-suggestion="False" data-oldsystem="https://batdongsan.com.vn" data-seller-api="https://batdongsan.com.vn/user-management-service" data-sug-api-b2b="https://suggestions.batdongsan.com.vn/suggest" data-sug-api-consumer="https://suggestions.batdongsan.com.vn/suggest" data-use-kong-gw="False" data-user-api="https://sellernetapi.batdongsan.com.vn" data-verify-token="c7a93640e1acd35ed4e6956e6f48f29c" data-wap="https://batdongsan.com.vn" data-web="https://batdongsan.com.vn" id="staticDomain" statsdomain="https://statistic.batdongsan.com.vn"></div>
# <div class="js__log-services-params" data-log-error-url="/Systems/Logging/LogError" data-log-info-url="/Systems/Logging/LogInfo"></div>
# <div data-page-hint="srp" id="page-params"></div>
# <div addon-image="https://staticfile.batdongsan.com.vn/images/no-image.png" id="addonImage"></div>
# <div data-disable-write-db="false" data-enable-new-label-verified="false" id="featureConfig"></div>
# <div class="re__bg-header">
# <header class="re__full-menu re__header re__hover-menu re__tablet-menu re__nohome js__menu-bar">
# <div class="re__container-sm">
# <div class="app-info">
# <div class="app-label">
# <a class="re__btn re__btn-se-ghost--md" href="javascript:void(0);">Táº£i á»©ng dá»¥ng</a>
# <a class="re__btn re__btn-se-ghost--md re__btn-icon--md re__iconApp" href="javascript:void(0);">
# <i class="re__icon-download-app"></i>
# </a>
# </div>
# <div class="app-popup">
# <div class="app-content">
# <div class="app-header">
# <div class="app-title">Táº£i á»©ng dá»¥ng</div>
# <div class="app-close js__close-app-popup"></div>
# </div>
# <div class="app-qr">
# <img alt="QR Code" class="qr-code" src="https://staticfile.batdongsan.com.vn/images/app/qr-app-adjust.png"/>
# </div>
# <div class="app-img">
# <a href="https://apps.apple.com/vn/app/batdongsan.com.vn/id866492094">
# <img alt="app store" class="img app-store" src="https://staticfile.batdongsan.com.vn/images/app/app-store.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=vn.com.batdongsan">
# <img alt="google play" class="img app-gplay" src="https://staticfile.batdongsan.com.vn/images/app/g-play.png"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="re__nav" id="naga">
# <a class="re__fleft re__back" href="javascript:void(0)" id="nav_back" rel="nofollow" title="Danh má»¥c">
# <div class="re__state-icon--md">
# <i class="re__icon-arrow-left"></i>
# </div>
# </a>
# <h2>
# <a href="https://batdongsan.com.vn" title="NhÃ  Äáº¥t">
# <img alt="Nền tảng bất động sản uy tín - Mua, BÃ¡n, Cho ThuÃª NhÃ  Äáº¥t ToÃ n Quá»c" error-image-src="https://staticfile.batdongsan.com.vn/images/logo/standard/red/logo.png" src="https://staticfile.batdongsan.com.vn/images/logo/standard/red/logo.svg" title="Nền tảng bất động sản uy tín - Mua, BÃ¡n, Cho ThuÃª NhÃ  Äáº¥t ToÃ n Quá»c"/>
# </a>
# </h2>
# <a class="re__fright re__save js__marked-products-redirect-url" data-href="/tin-da-luu" id="saveList" kyc-tracking-id="view_all_fav_listings" rel="nofollow" title="Danh má»¥c" tracking-label="loc=header">
# <div class="re__btn-content">
# <div class="re__state-icon--md">
# <i class="re__icon-heart"></i>
# </div>
# <span class="re__notification re__hide">
#                                         1
#                                     </span>
# </div>
# </a>
# <a class="re__fright re__menu" href="javascript:void(0)" id="nav_list" rel="nofollow" title="Danh má»¥c">
# <div class="re__btn-content">
# <div class="re__state-icon--md">
# <i class="re__icon-menu-hamburger"></i>
# </div>
# <span class="re__notification re__hide">
#                                     1
#                                 </span>
# </div>
# </a>
# </div>
# <div class="re__bg-pushmenu"></div>
# </div>
# <div class="re__menu-bar re__pushmenu re__pushmenu-right floating--right">
# <div class="re__control-menu">
# <div class="app-info">
# <div class="app-label">
# <a class="re__btn re__btn-se-ghost--md" href="javascript:void(0);">Táº£i á»©ng dá»¥ng</a>
# <a class="re__btn re__btn-se-ghost--md re__btn-icon--md re__iconApp" href="javascript:void(0);">
# <i class="re__icon-download-app"></i>
# </a>
# </div>
# <div class="app-popup">
# <div class="app-content">
# <div class="app-header">
# <div class="app-title">Táº£i á»©ng dá»¥ng</div>
# <div class="app-close js__close-app-popup"></div>
# </div>
# <div class="app-qr">
# <img alt="QR Code" class="qr-code" src="https://staticfile.batdongsan.com.vn/images/app/qr-app-adjust.png">
# </img></div>
# <div class="app-img">
# <a href="https://apps.apple.com/vn/app/batdongsan.com.vn/id866492094">
# <img alt="app store" class="img app-store" src="https://staticfile.batdongsan.com.vn/images/app/app-store.png"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=vn.com.batdongsan">
# <img alt="google play" class="img app-gplay" src="https://staticfile.batdongsan.com.vn/images/app/g-play.png"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div aria-label="Danh sÃ¡ch tin ÄÃ£ lÆ°u" class="re__login-group" data-microtip-position="bottom" role="tooltip">
# <div class="re__notification" id="notiSave">
# <div class="re__all-btn">
# <a class="re__btn re__btn-se-ghost--md re__btn-icon--md re__iconNotiSave">
# <i class="re__icon-heart"></i>
# </a>
# <i class="re__mnu-notify-icon-unread re__nqv" style="display: none"></i>
# </div>
# <div class="re__marked-products-popup" style="display: none;">
# <div class="re__header re__header-fix">Tin ÄÄng ÄaÌ lÆ°u</div>
# <div class="re__content">
# <p class="re__center" style="padding: 80px 0 80px;"><img alt="no data" src="https://staticfile.batdongsan.com.vn/images/empty-state.svg"/></p>
# </div>
# <div class="re__footer" style="display: none !important;">
# <a class="re__marked-products-view-more re__link-pr js__marked-products-redirect-url" data-href="/tin-da-luu" title="Xem tÃ¢Ìt caÌ" tracking-id="view_all_fav_listings" tracking-label="loc=header">
# <span>Xem táº¥t cáº£</span><i class="re__icon-arrow-right--sm"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div data-notification-library-url="https://static.batdongsan.com.vn/assets/bds-notification.js" id="divUserStt">
# <a class="re__btn re__btn-se-border--md re__btn-se-ghost--md" href="javascript:void(0);" id="kct_login" rel="nofollow" tracking-id="user-login-seller" tracking-label="loc=Header">ÄÄng nháº­p</a>
# <span class="re__line"></span>
# <a class="re__btn re__btn-pr-solid--md re__btn-se-ghost--md" href="javascript:void(0);" id="kct_username" rel="nofollow" tracking-id="sign-up-button-seller" tracking-label="loc=Header">ÄÄng kyÌ</a>
# </div>
# <div id="Header_UserControl_divPostProduct">
# <a class="re__btn re__btn-se-border--md" href="/nguoi-ban/dang-tin" id="linkPostProduct">ÄÄng tin</a>
# </div>
# </div>
# <div class="re__drop-menu">
# <div class="re__left-menu">
# <h2>
# <a href="https://batdongsan.com.vn">
# <img alt="KÃªnh thÃ´ng tin mua bÃ¡n, cho thuÃª nhÃ  Äáº¥t uy tín" error-image-src="https://staticfile.batdongsan.com.vn/images/logo/standard/red/logo.png" src="https://staticfile.batdongsan.com.vn/images/logo/standard/red/logo.svg" title="Batdongsan.com.vn"/>
# </a>
# </h2>
# </div>
# <div class="re__right-menu">
# <!--Header menu-->
# <div class="re__home-header-menu">
# <div class="re__home-header-menu">
# <ul class="re__dropdown-no-art--sm re__dropdown-navigative-menu">
# <li class="lv0 tablet">
# <a href="/sellernet/quan-ly-tin-rao-ban-cho-thue">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/litsting.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/litsting.svg"/>
# </span>
# <span class="text">Danh sÃ¡ch tin</span>
# </a>
# </li>
# <li class="lv0 tablet">
# <a href="/sellernet/quan-ly-khach-hang">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/notebook.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/notebook.svg"/>
# </span>
# <span class="text">Quáº£n lÃ½ khÃ¡ch hÃ ng</span>
# </a>
# </li>
# <li class="lv0 tablet">
# <a href="/sellernet/tin-tai-tro">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/ad.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/ad.svg"/>
# </span>
# <span class="text">Quáº£n lÃ½ tin tÃ i trá»£</span>
# </a>
# </li>
# <li class="lv0 tablet">
# <a href="/tin-da-luu">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/heart.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/heart.svg"/>
# </span>
# <span class="text">Tin ÄÄng ÄaÌ lÆ°u</span>
# </a>
# </li>
# <li class="lv0 tablet">
# <a href="https://batdongsan.com.vn">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/home.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/home.svg"/>
# </span>
# <span class="text">Trang chá»§</span>
# </a>
# </li>
# <li class="lv0">
# <a class="haslink" href="/nha-dat-ban">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/all.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/all.svg"/>
# </span>
# <span class="text">NhÃ  Äáº¥t bÃ¡n</span>
# </a>
# <ul class="re__dropdown-no-art--sm">
# <li class="lv1">
# <a class="haslink" href="/ban-can-ho-chung-cu">BÃ¡n cÄn há» chung cÆ°</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-can-ho-chung-cu-mini">BÃ¡n chung cÆ° mini, cÄn há» dá»ch vá»¥ <span class="new-label"></span></a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-nha-rieng">BÃ¡n nhÃ  riÃªng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-nha-biet-thu-lien-ke">BÃ¡n nhÃ  biá»t thá»±, liá»n ká»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-nha-mat-pho">BÃ¡n nhÃ  máº·t phá»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-shophouse-nha-pho-thuong-mai">BÃ¡n shophouse, nhÃ  phá» thÆ°Æ¡ng máº¡i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-dat-nen-du-an">BÃ¡n Äáº¥t ná»n dá»± Ã¡n</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-dat">BÃ¡n Äáº¥t</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-trang-trai-khu-nghi-duong">BÃ¡n trang tráº¡i, khu nghá» dÆ°á»¡ng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-condotel">BÃ¡n condotel</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-kho-nha-xuong">BÃ¡n kho, nhÃ  xÆ°á»ng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/ban-loai-bat-dong-san-khac">BÃ¡n loáº¡i báº¥t Äá»ng sáº£n khÃ¡c</a>
# </li>
# </ul>
# </li>
# <li class="lv0">
# <a class="haslink" href="/nha-dat-cho-thue">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/complex.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/complex.svg"/>
# </span>
# <span class="text">NhÃ  Äáº¥t cho thuÃª</span>
# </a>
# <ul class="re__dropdown-no-art--sm">
# <li class="lv1">
# <a class="haslink" href="/cho-thue-can-ho-chung-cu">Cho thuÃª cÄn há» chung cÆ°</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-can-ho-chung-cu-mini">Cho thuÃª chung cÆ° mini, cÄn há» dá»ch vá»¥ <span class="new-label"></span></a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-nha-rieng">Cho thuÃª nhÃ  riÃªng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-nha-biet-thu-lien-ke">Cho thuÃª nhÃ  biá»t thá»±, liá»n ká»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-nha-mat-pho">Cho thuÃª nhÃ  máº·t phá»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-shophouse-nha-pho-thuong-mai">Cho thuÃª shophouse, nhÃ  phá» thÆ°Æ¡ng máº¡i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-nha-tro-phong-tro">Cho thuÃª nhÃ  trá», phÃ²ng trá»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-van-phong">Cho thuÃª vÄn phÃ²ng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-sang-nhuong-cua-hang-ki-ot">Cho thuÃª, sang nhÆ°á»£ng cá»­a hÃ ng, ki á»t</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-kho-nha-xuong-dat">Cho thuÃª kho, nhÃ  xÆ°á»ng, Äáº¥t</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/cho-thue-loai-bat-dong-san-khac">Cho thuÃª loáº¡i báº¥t Äá»ng sáº£n khÃ¡c</a>
# </li>
# </ul>
# </li>
# <li class="lv0">
# <a class="haslink" href="/du-an-bat-dong-san" tracking-id="b2b-header-navigation">
# <span class="icon">
# <img class="lazyloaded" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/apartment.svg" src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/apartment.svg"/>
# </span>
# <span class="text">Dá»± Ã¡n</span>
# </a>
# <ul class="re__dropdown-no-art--sm">
# <li class="lv1">
# <a class="haslink" href="/du-an-can-ho-chung-cu">CÄn há» chung cÆ°</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-cao-oc-van-phong">Cao á»c vÄn phÃ²ng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-trung-tam-thuong-mai">Trung tÃ¢m thÆ°Æ¡ng máº¡i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-khu-do-thi-moi">Khu ÄÃ´ thá» má»i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-khu-phuc-hop">Khu phá»©c há»£p</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-nha-o-xa-hoi">NhÃ  á» xÃ£ há»i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-khu-nghi-duong-sinh-thai">Khu nghá» dÆ°á»¡ng, Sinh thÃ¡i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-khu-cong-nghiep">Khu cÃ´ng nghiá»p</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-biet-thu-lien-ke">Biá»t thá»±, liá»n ká»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-shophouse">Shophouse</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-nha-mat-pho">NhÃ  máº·t phá»</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/du-an-khac">Dá»± Ã¡n khÃ¡c</a>
# </li>
# </ul>
# </li>
# <li class="lv0 re__no-child">
# <a class="haslink" href="/tin-tuc">
# <span class="icon">
# <img class="lazyload" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/news.svg"/>
# </span>
# <span class="text">Tin tá»©c</span>
# </a><div class="re__arrrow"></div>
# </li>
# <li class="lv0">
# <a class="haslink" href="/wiki">
# <span class="icon">
# <img class="lazyload" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/wiki.svg"/>
# </span>
# <span class="text">Wiki BÄS</span>
# </a>
# <ul class="">
# <li class="lv1">
# <a class="haslink" href="/wiki/mua-bds">Mua BÄS</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/wiki/ban-bds">BÃ¡n BÄS</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/wiki/thue-bds">ThuÃª BÄS</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/wiki/tai-chinh">TÃ i chÃ­nh BÄS</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/wiki/quy-hoach-phap-ly">Quy hoáº¡ch - PhÃ¡p lÃ½</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/wiki/noi-ngoai-that">Ná»i - Ngoáº¡i tháº¥t</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/wiki/phong-thuy">Phong thá»§y</a>
# </li>
# </ul>
# </li>
# <li class="lv0 re__dropdown re__phan-tich-danh-gia">
# <a class="haslink" href="/phan-tich-danh-gia">
# <span class="icon">
# <img class="lazyload" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/barchart.svg"/>
# </span>
# <span class="text">PhÃ¢n tÃ­ch ÄÃ¡nh giÃ¡</span>
# </a>
# <ul class="re__dropdown-no-art--sm">
# <li class="lv1">
# <a class="haslink" href="/phan-tich-danh-gia/bieu-do-gia">Biá»u Äá» giÃ¡</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/phan-tich-danh-gia/video-danh-gia">Video ÄÃ¡nh giÃ¡</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="https://research.batdongsan.com.vn/">BÃ¡o cÃ¡o thá» trÆ°á»ng</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/phan-tich-danh-gia/goc-nhin-chuyen-gia">GÃ³c nhÃ¬n chuyÃªn gia</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/interaktivestory">Interkative Story</a>
# </li>
# </ul>
# </li>
# <li class="lv0 re__dropdown re__danh-ba">
# <a class="nolink" href="javascript:void(0);">
# <span class="icon">
# <img class="lazyload" data-src="https://staticfile.batdongsan.com.vn/images/mobile/icons/24x24/outlined/notebook.svg"/>
# </span>
# <span class="text">Danh báº¡</span>
# </a>
# <ul class="re__dropdown-no-art--sm">
# <li class="lv1">
# <a class="haslink" href="/nha-moi-gioi">NhÃ  mÃ´i giá»i</a>
# </li>
# <li class="lv1">
# <a class="haslink" href="/doanh-nghiep">Doanh nghiá»p</a>
# </li>
# </ul>
# </li>
# <li class="re__btn-menu lv0">
# <span class="re__btn re__btn-se-ghost--md re__btn-icon--md">
# <i class="re__icon-browse"></i>
# </span>
# <ul class="re__bg"></ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="clear"> </div>
# </div>
# </div>
# </header>
# </div>
# </div>
# <div class="re__banner-container js__banner-left">
# <!-- Banner skycrapper web -->
# <div class="ban_wide_scroll re__visible-item re__banner_ads_backup" id="ban_wide_left">
# <a href="https://doanhnghiep.batdongsan.com.vn/dangtin0dong?utm_source=direct&amp;utm_medium=banner &amp;utm_campaign=ctkm_tindang_hcmc" rel="nofollow" target="_blank">
# </a>
# <img alt="Banner quáº£ng cÃ¡o" src="https://staticfile.batdongsan.com.vn/images/banner_ads/banner_web_skycrapper_left.png" width="100%">
# </img></div>
# <!-- Banner skycrapper web -->
# </div>
# <div class="re__banner-container js__banner-right">
# <div id="ban_wide_right"></div>
# </div>
# <div class="popupMarking save" style="display: none">
# <i class="re__icon-heart-pressed"></i>
# <span> Lưu tin thành công</span>
# </div>
# <div class="popupMarking unsave" style="display: none">
# <i class="re__icon-heart"></i>
# <span> Đã bỏ lưu tin</span>
# </div>
# <div class="re__main" itemprop="about">
# <div class="popup popupcontact js__popup-alert js__popup-contact-leadgen"></div>
# <input id="activeTxtSelect" type="hidden" value="1"/>
# <div class="re__srp re__main-content-layout js__main-container">
# <div data-locations-services-params='{"getCitiesUrl":"/Product/ProductSearch/GetCities","getDistrictsUrl":"/Product/ProductSearch/GetDistricts","getStreetsByDistrictIdsUrl":"/Product/ProductSearch/GetStreetsByDistrictIds","getWardsByDistrictIdsUrl":"/Product/ProductSearch/GetWardsByDistrictIds","getProjectsByDistrictIdsUrl":"/Product/ProductSearch/GetProjectsByDistrictIds"}' style="display: none"></div>
# <div class="re__advanced-filter-modal-container js__advanced-filter-modal-container" id="AdvancedFilterModal">
# <div class="re__advanced-filter-modal js__advanced-filter-modal">
# <div class="header">
# <div class="title">
# <span>Bá» lá»c</span>
# </div>
# <div class="re__close-advanced-modal">
# <i class="re__icon-close-no-circle js__close-advanced-modal"> </i>
# </div>
# </div>
# <div class="body">
# <div class="re__switch-button-wrapper">
# <button class="re__switch-sell-button active js__switch-sell-button">TÃ¬m mua</button>
# <button class="re__switch-rent-button js__switch-rent-button">TÃ¬m thuÃª</button>
# </div>
# <div data-product-type="PRODUCT_4_SELL" data-value="324" id="advFilterCategory">
# <div class="re__asset-type-wrapper">
# <div class="re__asset-type-title">Loại bất động sản</div>
# <div class="re__asset-type-tag-wrapper">
# <button class="re__asset-type-add js__asset-type-add">
# <i class="re__icon-plus"></i>
# <span>ThÃªm</span>
# </button>
# </div>
# </div>
# <div class="re__advanced-filter-selection js__advanced-filter-selection hidden">
# <div class="re__advanced-filter-modal-container js__advanced-filter-modal-selection">
# <div class="re__advanced-filter-modal js__advanced-children-filter-modal">
# <div class="header">
# <div class="title">
# <i class="re__icon-arrow-left js__back-overview-modal"></i>
# <span class="js__current-children-filter-title"></span>
# </div>
# <div class="re__close-children-advanced-modal js__close-advanced-filter-modal-selection">
# ...
#                     }, 500)
#                 }
#             })(20);
#         </script>
# <input id="ajaxAdButler" type="hidden" value='{"slaMonitorApi":"https://api.batdongsan.com.vn/sla-monitor-service/api/v1/SuspicousAdServes","adButlerApi":"https://promote.batdongsan.com.vn/","adButlerPayload":{"ID":"183272","setID":"555166","type":"json","place":0,"clickmode":"callback","_abdk_json":{"page":"[\u0027Nh\u00E0 \u0111\u1EA5t b\u00E1n\u0027,\u0027B\u00E1n c\u0103n h\u1ED9 chung c\u01B0\u0027]","search_sell_kind":"[\u0027Nh\u00E0 \u0111\u1EA5t b\u00E1n\u0027]","product_for_sell":"[\u0027Nh\u00E0 \u0111\u1EA5t b\u00E1n\u0027,\u0027B\u00E1n c\u0103n h\u1ED9 chung c\u01B0\u0027]","search_province":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_district":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_ward":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_street":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_project":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_price":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_direction":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_area":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_room":"[\u0027T\u1EA5t c\u1EA3\u0027]","search_media":"[\u0027T\u1EA5t c\u1EA3\u0027]","page_type":"[\u0027listing\u0027]"}},"htmlApis":{"premiumAds":"/ProjectNet/ProjectList/GetPremiumAdsByLegacyIds","nativeListing":"/Product/ProductListing/GetSponsoredAdsByProductId","customListing":"/Product/ProductListing/GetCustomAdsByInfo"},"queryString":{"value":"?pId=275\u0026cateId=324\u0026pageType=1\u0026lang=1\u0026pType=38\u0026subAlias=\u0026rawUrl=ban-can-ho-chung-cu","hasValue":true},"productPublishes":[{"productId":42811574},{"productId":39114589},{"productId":42777869},{"productId":42714850},{"productId":42793311},{"productId":41850299},{"productId":42810650},{"productId":42789560},{"productId":42800493},{"productId":42665977},{"productId":42509557},{"productId":42287004},{"productId":42810018},{"productId":42603817},{"productId":42569053},{"productId":42263840},{"productId":42809587},{"productId":42809540},{"productId":42809452},{"productId":42640676}],"productSuggestes":[],"pageSizeMax":20,"adsType":"CustomListing","isEnableSponsorAdsSlot2":true}'>
# <script searching-suggestions-service-params='{"hours":2.0,"trackingInfo":{"id":"search-bar-suggestion","project":"project","location":"location","history":"history","nearMe":"near me"}}'></script>
# <script src="https://staticfile.batdongsan.com.vn/lib/jquery-swiper/js/filestatic.ver1.msvbds.swiper.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.verm-c499fc3.msvbds.FrontEnd.CardController.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Product/Binnova/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.ProductListBinnova.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Product/Binnova/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.PromotedProject.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Product/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.Faq.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/lib/bds-tooltip/filestatic.ver4.msvbds.bds-tooltip.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Common/Services/filestatic.verm-c499fc3.msvbds.FrontEnd.BadReportProductsServices.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Common/HelperControllers/filestatic.verm-c499fc3.msvbds.FrontEnd.StaticPopupController.min.js" type="text/javascript"></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Product/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.SaveSearchAlert.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#         if (window.FrontEnd && window.FrontEnd.Product) {
#             window.FrontEnd_Product_SaveSearchAlert = new FrontEnd.Product.SaveSearchAlert({
#                 request: {"Token":null,"IsSave":false,"Title":null,"TitleSubscribe":null,"LocationTitle":null,"CategoryTitle":null,"Message":null,"UserId":null,"Email":null,"ProductSubscribeId":null,"IsSubscribe":false,"IsFixSearchBox":false,"IsDisplayBox":false,"SearchRequest":{"PageSize":20,"PageIndex":1,"TypeOfProduct":38,"CateId":324,"CityCode":"","DistrictId":0,"WardId":-1,"StreetId":-1,"ProjectId":0,"AreaLevel":-1,"PriceLevel":-1,"Room":-1,"Direction":-1,"CreateById":0,"MaxArea":null,"MinArea":null,"MaxPrice":null,"MinPrice":null,"Keyword":"","TabIndex":0,"IsRefreshCache":false,"SortValue":0,"Top":6,"RawUrl":"/ban-can-ho-chung-cu","Country":"VN","TextSearch":null,"PageId":0,"ExcludeProducts":null,"SortFieldOption":null,"Sort":0,"HasImage":false,"TypeMeta":0,"CreateByUser":0,"ProductId":0,"SubCateId":0,"IsTags":false,"TagID":0,"SearchSavedName":null,"SearchTag":null,"IsMobile":false,"IsSearch":false,"ListSubCateId":null,"TypeSearch":0,"HashAlias":null,"IsSuggestion":false,"PageSizeMin":0,"NumberOfPageToFetch":0,"TotalAll":0,"IsArea":false,"ExtendAlias":"","CurrentUrl":null,"CateIds":null,"Cities":null,"Districts":null,"Wards":null,"Streets":null,"Projects":null,"IsProductContext":false,"TypeOfProductOrigin":0,"IsHomePage":false,"CategoryIdsAsString":"","CategoryIdsAsStringSearch":null,"DistrictIdsAsStringSearch":null,"PriceAsStringSearch":null,"IsLoadCache":true,"CategoryIds":[],"DistrictIdsAsString":"","DistrictIds":[],"WardIdsAsString":"","WardIds":[],"StreetIdsAsString":"","StreetIds":[],"ProjectIdsAsString":"","ProjectIds":[],"SubProjectIdsAsString":"","SubProjectIds":[],"RoomNumbersAsString":"","RoomNumbers":[],"DirectionsAsString":"","Directions":[],"MediasAsString":"","Medias":[],"VerificationsAsString":"","Verifications":[],"IsMultipleSearchPricingHistory":false,"IsMultipleSearch":false,"IsMultipleLocation":false,"IsMultipleSearchOrigin":false,"IsSaveSearchScope":true,"LocationIdsFlowAsString":"_0_0_0_0","LocationIdsFlow":["_0_0_0_0"],"IsSRPForSalePage":true,"IsMultipleLocationLevel3":false,"IsMultipleLocationLevel2":false,"IncludeExpiredListing":null,"IsScopeSearchOnlyCateLocationProject":true,"IsFreetextSearch":false,"IsOrigin":null,"FrontageLevel":-1,"RoadLevel":-1,"BalconDirectionsAsString":null,"BalconDirections":[],"AvailableTime":-1,"ElectricityPrice":-1,"WaterPrice":-1,"InternetPrice":-1,"UtilityAsString":"","Utility":[],"AgentVerificationsAsString":"","AgentVerifications":[],"TypeOfLayout":"","ProductSearchType":0,"Viewport":null,"PolygonString":null,"IsSplitQuery":false,"BoxType":0,"IsAjaxLoading":false,"IsLog":false},"ProductDetail":{"UserId":null,"Email":null,"TypeOfProduct":38,"CateIds":"324","CityCodes":"","DistrictIds":"","WardIds":"","StreetIds":"","Rooms":"","Directions":null,"BalconDirections":null,"Medias":null,"MinPrice":null,"MaxPrice":null,"ConvertedPrice":null,"MinArea":null,"MaxArea":null,"ConvertedArea":null,"ProjectIds":"","Keywords":null,"SearchTitle":null,"SearchUrl":null,"ScheduleType":0,"IsActive":true,"CreatedTime":"0001-01-01T00:00:00","UpdatedTime":"0001-01-01T00:00:00","Id":0}}
#                             });
#         }
#     </script>
# <script src="https://staticfile.batdongsan.com.vn/js/Product/filestatic.verm-c499fc3.msvbds.FrontEnd.Product.VerifiedListing.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#         if (window.FrontEnd && window.FrontEnd.Product && FrontEnd.Product.VerifiedListing) {
#             var FrontEnd_Product_VerifiedListing = new FrontEnd.Product.VerifiedListing({ IsSell: true });
#         }
#     </script>
# <script boosting-cta-params='{"getBoostingCtaPopupUrl":"/Product/ProductListing/GetBoostingCtaPopup","getBoostingCtaSectionsUrl":"/Product/ProductListing/GetBoostingCtaSections","productType":38}'></script>
# <script src="https://staticfile.batdongsan.com.vn/js/Common/UIHelpers/filestatic.verm-c499fc3.msvbds.FrontEnd.BoostingCtaHelper.min.js" type="text/javascript"></script>
# <script>
#             new window.FrontEnd.BoostingCtaHelper().ShowBoostingCtaSection();
#         </script>
# <script src="https://staticfile.batdongsan.com.vn/js/Product/Srp/filestatic.verm-c499fc3.msvbds.FrontEnd.Srp.ProAgent.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#         (function waitBoxListingSearchVMapSearch() {
#             if (window.FrontEnd && window.FrontEnd.Product && window.FrontEnd.Product.BoxListingSearchAdvancedFilter) {
#                 window.FrontEnd.ListingSearchMapSearch = new window.FrontEnd.Product.BoxListingSearchAdvancedFilter({
#                     PRODUCT_TYPES: {
#                         SELL: 38,
#                         RENT: 49
#                         },
#                     searchingHistoriesServicesParams: '{&quot;maxLength&quot;:20,&quot;syncTimeSearchingHistories&quot;:5.0,&quot;syncSearchingHistoriesUrl&quot;:&quot;/Product/ProductSearch/SyncSearchingHistories&quot;,&quot;removeSearchingHistoryUrl&quot;:&quot;/Product/ProductSearch/RemoveSearchingHistory&quot;}',
#                     TRACKING_CONSTANTS: {
#                         TRACKING_ID: 'multisearch-filter-apply',
#                         TRACKING_LABEL_LOC: 'SRP For Sale'
#                     },
#                     ENABLE_MULTIPLE_SEARCHING_HISTORIES: true,
#                     API_DISTRICTS_SUGGESTION: '/Systems/Api/GetDistrictsByCity',
#                     API_POPULAR_SEARCH: '/Product/ProductSearch/GetPopularSearch',
#                     LastSearch: "null",
#                 });
#             } else {
#                 setTimeout(waitBoxListingSearchVMapSearch, 100);
#             }
#         })();
#     </script>
# <script type="text/javascript">
#         if (localStorage && localStorage.setItem) {
#             localStorage.setItem('AdbutlerConfig', JSON.stringify({
#                 MID: parseInt("183272"),
#                 API: "https://promote.batdongsan.com.vn/"
#             }));
#         }
#     </script>
# <script type="text/javascript">
#             (function callJQueryBraze() {
#                 if (window.braze) {
#                     if (window.braze.isPushSupported()) {
#                         braze.requestPushPermission();
#                     } else {
#                         setTimeout(callJQueryBraze, 100)
#                     }
#                 } else {
#                     setTimeout(callJQueryBraze, 100)
#                 }
#             })();
#         </script>
# <link href="https://staticfile.batdongsan.com.vn/css/web/filestatic.ver10.msvbds.survey.min.css" rel="stylesheet"/>
# <script src="https://staticfile.batdongsan.com.vn/js/Survey/filestatic.ver25.msvbds.Survey.min.js" type="text/javascript"></script>
# <div class="re__survey-body re__survey-listing-verified re__survey-template js__survey-ux-listing-verified" sid="listing-verified" surl="https://surveys.hotjar.com/9dbd38b5-a4e5-49b4-bb20-1fb132cfc187">
#         Báº¡n tháº¥y tháº¿ nÃ o vá» <strong>Tin xÃ¡c thá»±c</strong> cá»§a Batdongsan.com.vn? <br/> HÃ£y chia sáº» tráº£i nghiá»m cá»§a báº¡n cho chÃºng tÃ´i nhÃ©!
#     </div>
# <script type="text/javascript">
#         Survey.init({"lv":true});
#     </script>
# <script async="" data-cfasync="false" src="https://staticfile.batdongsan.com.vn/js/Tracking/filestatic.verm-c499fc3.msvbds.PPPImpressionTracking.min.js" type="text/javascript"></script>
# <script>
#         (function callFunctionOb(time = 30) {
#             let canInitPPPTracking = window.turnstileLoaded || ('False' !== "True");
#             if (canInitPPPTracking && window.PPPImpressionTracking && time > 0) {
#                 window.PPP_ImpressionTracking = new PPPImpressionTracking({
#                     PPPTurnstileId: 'ppp-turnstile',
#                     ImpressionTrackingApiUrl: '/Systems/Api/CreatePPPImpressionTracking'
#                 });
#             } else {
#                 setTimeout(() => {
#                     callFunctionOb(time - 1);
#                 }, 100);
#             }
#         })();
#     </script>
# <script type="text/javascript">
#         window.Tracking && window.Tracking.init && window.Tracking.init();
#         (function waitKycLoadingHelper(time) {
#             if (window.FrontEnd && window.FrontEnd.KycLoadingHelper) {
#                 new window.FrontEnd.KycLoadingHelper();
#             }
#             else if (time) {
#                 setTimeout(function () {
#                     waitKycLoadingHelper(time - 1);
#                 }, 500);
#             }
#         })(20);
#     </script>
# <script>
#             window.unlFeaturesBottom = [{"f":"cplus-9160_ai-team-chat-bot","v":"cplus-9160_ai-team-chat-bot_experiment","s":"1"},{"f":"cplus-9046_new-pa-entry-point","v":"cplus-9046_new-pa-entry-point_version-c","s":"1"},{"f":"cplus-8015_implement-ui-message","v":"cplus-8015_implement-ui-message_version-a","s":"1"},{"f":"cplus-8842_new-label-verified-listing","v":"disabled","s":"0"},{"f":"cplus-9084_unified-search-srp-map-and-list","v":"cplus-9084_unified-search-srp-map-and-list_enabled","s":"1"},{"f":"cplus-8350_new-categories-mini-apartment","v":"","s":"1"},{"f":"cplus-8431-braze-web-push","v":"","s":"1"},{"f":"cplus-7677-kong-api-gateway-integration","v":"","s":"0"},{"f":"cloudflare-turnstile-viewphone","v":"","s":"0"},{"f":"cplus-8597_Label-cate-mini-apartment","v":"","s":"1"},{"f":"BDSMON2-PIVOT-ENTRY-TOP-MENU-CONSUMER","v":"","s":"1"},{"f":"cplus_7967-image-optimize","v":"","s":"1"},{"f":"cplus-8907_banner-placeholder-on-map-search","v":"","s":"0"},{"f":"BDSMON2-PIVOT-CONSUMER","v":"","s":"1"},{"f":"cloudflare-turnstile-ppp","v":"","s":"0"},{"f":"cplus-8127-move-seo-controller-to-seo-listing-service","v":"","s":"1"},{"f":"bdspp-947-leadgen-ldp","v":"","s":"0"},{"f":"cplus-5590-sentry","v":"","s":"1"},{"f":"cplus-8389_ms-sort-render-srp-ajax","v":"","s":"0"},{"f":"ppp-impression-tracking","v":"","s":"1"},{"f":"onboarding-new-users","v":"","s":"0"},{"f":"cplus-7797_promote-listing-verified-for-city","v":"","s":"1"},{"f":"cplus-7974-braze-in-app-message","v":"","s":"0"},{"f":"cplus-7406_new-api-suggestion","v":"","s":"0"},{"f":"cplus-8336-customized-srp-bottom-pages","v":"","s":"1"},{"f":"cplus-8478_KYC-bookmark-listing","v":"","s":"1"},{"f":"cplus-9386_pa-link-parameters","v":"","s":"1"},{"f":"cplus-5820_survey-user-experience-with-listing-verified","v":"","s":"1"},{"f":"cplus-8973_qr-code-header","v":"","s":"1"},{"f":"cplus_7964-js-optimize","v":"","s":"0"},{"f":"cplus-7639-kyc-flow-to-save-cost","v":"","s":"0"},{"f":"cplus-7974-braze-integration","v":"","s":"1"}];
#         </script>
# <script src="https://staticfile.batdongsan.com.vn/js/Tracking/filestatic.ver14.msvbds.Tracking.Unleash.min.js" type="text/javascript"></script>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'934fd9292f490516',t:'MTc0NTQzNzM5MC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script><script crossorigin="anonymous" data-cf-beacon='{"rayId":"934fd9292f490516","serverTiming":{"name":{"cfExtPri":true,"cfL4":true,"cfSpeedBrain":true,"cfCacheStatus":true}},"version":"2025.4.0-1-g37f21b1","token":"2559dc66ad8646d0be1eff7b03983020"}' defer="" integrity="sha512-ZpsOmlRQV6y907TI0dKBHq9Md29nnaEIPlkf84rnaERnq6zvWvPUqr2ft8M1aS28oN72PdrCzSjY4U6VaAw1EQ==" src="https://static.cloudflareinsights.com/beacon.min.js/vcd15cbe7772f49c399c6a5babf22c1241717689176015"></script>
# </input></input></input></body>
# </html>
